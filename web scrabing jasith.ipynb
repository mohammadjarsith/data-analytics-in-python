# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
ceo=("https://aflcio.org/paywatch/highest-paid-ceos")

# %%
response=requests.get(ceo)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# ...

# %%
name=soup.select("td.views-field-name")

# %%
name
# Out:
# [<td class="views-field views-field-name" headers="view-name-table-column">Jeff Green          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Vladimir Tenev          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Peter Rawlinson          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Robert Scaringe          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Jason Kelly          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Peter Kern          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">David Zaslav          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">David Baszucki          </td>,
#  <td class="views-field views-field-name" headers="view-name-table-column">Jason Gardner          </td>,
# ...

# %%
year=soup.select("td.views-field-year")

# %%
year
# Out:
# [<td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
#  <td class="priority-medium views-field views-field-year" headers="view-year-table-column">2021          </td>,
# ...

# %%
pay=soup.select("td.is-active")

# %%
pay
# Out:
# [<td class="views-field views-field-total is-active" headers="view-total-table-column">$834,959,367          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$796,124,647          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$565,591,512          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$422,140,679          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$380,742,276          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$296,247,749          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$246,573,481          </td>,
#  <td class="views-field views-field-total is-active" headers="view-total-table-column">$232,786,391          </td>,
# ...

# %%
import pandas

# %%
ceolist=pandas.DataFrame(name,columns=['ceoname'])

# %%
ceolist
# Out:
#
# 0            Jeff Green
# 1        Vladimir Tenev
# 2       Peter Rawlinson
# 3       Robert Scaringe
# 4           Jason Kelly
# 5            Peter Kern
# 6          David Zaslav
# 7        David Baszucki
# 8         Jason Gardner
# 9       David Steinberg
# 10         Andrew Jassy
# 11             G. Mikan
# 12         Scott Mercer
# 13    Patrick Gelsinger
# 14       Barry McCarthy
# 15    William McDermott
# 16       Michael Levitt
# 17         R.J. Pittman
# 18  Travis VanderZanden
# 19         George Kurtz

# %%
ceolist["name"]=name

# %%
ceolist["year"]=year

# %%
ceolist["pay"]=pay

# %%
ceolist
# Out:
#                                                               name  \
# 0            Jeff Green                     [Jeff Green          ]
# 1        Vladimir Tenev                 [Vladimir Tenev          ]
# 2       Peter Rawlinson                [Peter Rawlinson          ]
# 3       Robert Scaringe                [Robert Scaringe          ]
# 4           Jason Kelly                    [Jason Kelly          ]
# 5            Peter Kern                     [Peter Kern          ]
# 6          David Zaslav                   [David Zaslav          ]
# 7        David Baszucki                 [David Baszucki          ]
# 8         Jason Gardner                  [Jason Gardner          ]
# 9       David Steinberg                [David Steinberg          ]
# 10         Andrew Jassy                   [Andrew Jassy          ]
# 11             G. Mikan                       [G. Mikan          ]
# 12         Scott Mercer                   [Scott Mercer          ]
# ...

# %%
ceo
