# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
ceo=("https://insideiim.com/ceos-top-100-companies-india-many-mba")

# %%
response=requests.get(ceo)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <base href="/"/> <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <link as="font" crossorigin="" href="\assets\fonts\slick.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="\assets\fonts\slick.ttf" rel="preload" type="font/ttf"/>
# <link as="style" href="\assets\css\slick.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="\assets\css\slick-theme.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link href="manifest_new.json" rel="manifest"/>
# <!-- icon in the highest resolution we need it for -->
# <link href="\assets\icons\icon-192x192.png" rel="icon" sizes="192x192"/>
# <!-- reuse same icon for Safari -->
# <link href="\assets\icons\icon-512x512.png" rel="apple-touch-icon"/>
# <!-- multiple icons for IE -->
# ...

# %%
name=soup.select("tr+ tr td:nth-child(2)")

# %%
name
# Out:
# [<td data-sheets-value='{"1":2,"2":"Sanjiv Singh"}'>Sanjiv Singh</td>,
#  <td data-sheets-value='{"1":2,"2":"Mukesh Ambani"}'>Mukesh Ambani</td>,
#  <td data-sheets-value='{"1":2,"2":"Arijit Basu"}'>Arijit Basu</td>,
#  <td data-sheets-value='{"1":2,"2":"Guenter Butschek"}'>Guenter Butschek</td>,
#  <td data-sheets-value='{"1":2,"2":"Rajesh Mehta"}'>Rajesh Mehta</td>,
#  <td data-sheets-value='{"1":2,"2":"D. Rajkumar"}'>D. Rajkumar</td>,
#  <td data-sheets-value='{"1":2,"2":"Mukesh Kumar Surana"}'>Mukesh Kumar Surana</td>,
#  <td data-sheets-value='{"1":2,"2":"Shashi Shanker"}'>Shashi Shanker</td>,
#  <td data-sheets-value='{"1":2,"2":"Sutirtha Bhattacharya"}'>Sutirtha Bhattacharya</td>,
#  <td data-sheets-value='{"1":2,"2":"Rajesh Gopinathan"}'>Rajesh Gopinathan</td>,
#  <td data-sheets-value='{"1":2,"2":"T.V. Narendran"}'>T.V. Narendran</td>,
#  <td data-sheets-value='{"1":2,"2":"Chanda Kochhar"}'>Chanda Kochhar</td>,
# ...

# %%
company=soup.select("tr+ tr td:nth-child(1)")

# %%
company
# Out:
# [<td data-sheets-value='{"1":2,"2":"Indian Oil Corporation"}'>Indian Oil Corporation</td>,
#  <td data-sheets-value='{"1":2,"2":"Reliance Industries"}'>Reliance Industries</td>,
#  <td data-sheets-value='{"1":2,"2":"State Bank of India"}'>State Bank of India</td>,
#  <td data-sheets-value='{"1":2,"2":"Tata Motors"}'>Tata Motors</td>,
#  <td data-sheets-value='{"1":2,"2":"Rajesh Exports"}'>Rajesh Exports</td>,
#  <td data-sheets-value='{"1":2,"2":"Bharat Petroleum"}'>Bharat Petroleum</td>,
#  <td data-sheets-value='{"1":2,"2":"Hindustan Petroleum"}'>Hindustan Petroleum</td>,
#  <td data-sheets-value='{"1":2,"2":"Oil &amp; Natural Gas Corporation"}'>Oil &amp; Natural Gas Corporation</td>,
#  <td data-sheets-value='{"1":2,"2":"Coal India"}'>Coal India</td>,
#  <td data-sheets-value='{"1":2,"2":"Tata Consultancy Services"}'>Tata Consultancy Services</td>,
#  <td data-sheets-value='{"1":2,"2":"Tata Steel"}'>Tata Steel</td>,
# ...

# %%
graduationcollege=soup.select("tr+ tr td:nth-child(4)")

# %%
graduationcollege
# Out:
# [<td data-sheets-value='{"1":2,"2":"IIT Roorkee"}'>IIT Roorkee</td>,
#  <td data-sheets-value='{"1":2,"2":"UDCT"}'>UDCT</td>,
#  <td data-sheets-value='{"1":2,"2":"IIT Delhi"}'>IIT Delhi</td>,
#  <td data-sheets-value='{"1":2,"2":"Baden-Württemberg Cooperative State University"}'>Baden-Württemberg Cooperative State University</td>,
#  <td data-sheets-value='{"1":2,"2":"NA"}'>NA</td>,
#  <td data-sheets-value='{"1":2,"2":"IIT Madras"}'>IIT Madras</td>,
#  <td data-sheets-value='{"1":2,"2":"Data Unavailable"}'>Data Unavailable</td>,
#  <td data-sheets-value='{"1":2,"2":"ISM Dhanbad"}'>ISM Dhanbad</td>,
#  <td data-sheets-value='{"1":2,"2":"Presidency College, Kolkata"}'>Presidency College, Kolkata</td>,
#  <td data-sheets-value='{"1":2,"2":"NIT Trichy"}'>NIT Trichy</td>,
#  <td data-sheets-value='{"1":2,"2":"NIT Trichy"}'>NIT Trichy</td>,
#  <td data-sheets-value='{"1":2,"2":"Jai Hind College, ICAI"}'>Jai Hind College, ICAI</td>,
# ...

# %%
import pandas

# %%
ceolist=pandas.DataFrame(name,columns=['ceoname'])

# %%
ceolist
# Out:
#                    ceoname
# 0             Sanjiv Singh
# 1            Mukesh Ambani
# 2              Arijit Basu
# 3         Guenter Butschek
# 4             Rajesh Mehta
# ..                     ...
# 95          Pramit Jhaveri
# 96               Vinay Sah
# 97  R.A. Sankara Narayanan
# 98            Rahul Mammen
# 99              Manoj Gaur
#
# [100 rows x 1 columns]

# %%
ceolist["name"]=name

# %%
ceolist["company"]=company

# %%
ceolist["graduationcollege"]=graduationcollege

# %%
ceolist
# Out:
#                    ceoname                      name  \
# 0             Sanjiv Singh            [Sanjiv Singh]
# 1            Mukesh Ambani           [Mukesh Ambani]
# 2              Arijit Basu             [Arijit Basu]
# 3         Guenter Butschek        [Guenter Butschek]
# 4             Rajesh Mehta            [Rajesh Mehta]
# ..                     ...                       ...
# 95          Pramit Jhaveri          [Pramit Jhaveri]
# 96               Vinay Sah               [Vinay Sah]
# 97  R.A. Sankara Narayanan  [R.A. Sankara Narayanan]
# 98            Rahul Mammen            [Rahul Mammen]
# 99              Manoj Gaur              [Manoj Gaur]
#
#                      company                                 graduationcollege
# 0   [Indian Oil Corporation]                                     [IIT Roorkee]
# 1      [Reliance Industries]                                            [UDCT]
# 2      [State Bank of India]                                       [IIT Delhi]
# ...

# %%
ceo
# Out:
# 'https://insideiim.com/ceos-top-100-companies-india-many-mba'

# %%
ceolist.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\jarsith llyear b.sc., cs.csv")
